# %%
import torch
import sys
sys.path.append("/opt/tiger/SimCLR")
from data_aug.face_dataset import FaceDataset

# %%
dataset = FaceDataset("/mnt/bn/data-tns-live-llm/leon/experiments/llm/face/cropped_second_stage_imgs/")
print(len(dataset))
# Out:
# 292

# %%
import cv2 as cv
from torchvision.transforms import transforms
img = cv.imread("/opt/tiger/SimCLR/label.jpg")
print(img.shape)
normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
)
resize = transforms.Resize((224,224))
transform = transforms.Compose([
    transforms.ToTensor(),
    resize, 
    normalize
    ])
# Out:
# (480, 640, 3)

# %%
img = transform(img)
print(img.shape)
print(img)
print(torch.mean(img))

# %%
from torch.utils.data import DataLoader
train_loader = DataLoader(dataset, batch_size=16, shuffle=True,
num_workers=10, pin_memory=True, drop_last=True)

# %%
print(len(train_loader))
# Out:
# 18

# %%
for img, label in train_loader:
    img = torch.cat(img,dim=0)
    label = torch.cat(label,dim=0)
    print(len(img))
    print(len(label))
    print(img)
    print(label)
    break
# Out:
# 32
# 32
# tensor([[[[-1.5185e+00, -1.5185e+00, -1.5115e+00,  ..., -1.7034e+00,
#            -1.7069e+00, -1.7069e+00],
#           [-1.5185e+00, -1.5185e+00, -1.5115e+00,  ..., -1.7034e+00,
#            -1.7069e+00, -1.7069e+00],
#           [-1.5143e+00, -1.5143e+00, -1.5073e+00,  ..., -1.6908e+00,
#            -1.6899e+00, -1.6899e+00],
#           ...,
#           [-1.5611e+00, -1.5611e+00, -1.5787e+00,  ...,  3.3676e-02,
#             3.1482e-02,  3.1482e-02],
#           [-1.5357e+00, -1.5357e+00, -1.5550e+00,  ...,  5.8698e-02,
#             5.6940e-02,  5.6940e-02],
#           [-1.5357e+00, -1.5357e+00, -1.5550e+00,  ...,  5.8698e-02,
#             5.6940e-02,  5.6940e-02]],
#
#          [[-1.1078e+00, -1.1078e+00, -1.1007e+00,  ..., -1.5944e+00,
#            -1.5980e+00, -1.5980e+00],
#           [-1.1078e+00, -1.1078e+00, -1.1007e+00,  ..., -1.5944e+00,
#            -1.5980e+00, -1.5980e+00],
#           [-1.1035e+00, -1.1035e+00, -1.0968e+00,  ..., -1.5815e+00,
#            -1.5807e+00, -1.5807e+00],
#           ...,
#           [-1.4665e+00, -1.4665e+00, -1.4827e+00,  ...,  4.4400e-01,
#             4.4176e-01,  4.4176e-01],
#           [-1.4405e+00, -1.4405e+00, -1.4585e+00,  ...,  4.6958e-01,
#             4.6779e-01,  4.6779e-01],
#           [-1.4405e+00, -1.4405e+00, -1.4585e+00,  ...,  4.6958e-01,
#             4.6779e-01,  4.6779e-01]],
#
#          [[-3.4039e-01, -3.4039e-01, -3.3323e-01,  ..., -8.7712e-01,
#            -8.8070e-01, -8.8070e-01],
#           [-3.4039e-01, -3.4039e-01, -3.3323e-01,  ..., -8.7712e-01,
#            -8.8070e-01, -8.8070e-01],
#           [-3.3607e-01, -3.3607e-01, -3.2847e-01,  ..., -8.6428e-01,
#            -3.4664e-01, -3.3754e-01],
#           [-1.6316e+00, -1.6653e+00, -1.6804e+00,  ..., -3.3393e-01,
#            -3.3118e-01, -3.4045e-01],
#           [-1.6115e+00, -1.6823e+00, -1.7346e+00,  ..., -3.7580e-01,
#            -3.7373e-01, -3.7255e-01],
#           ...,
#           [-1.5105e+00, -1.5093e+00, -1.5085e+00,  ...,  2.1011e+00,
#             2.1025e+00,  2.1114e+00],
#           [-1.5105e+00, -1.5105e+00, -1.5057e+00,  ...,  2.1445e+00,
#             2.1447e+00,  2.1455e+00],
#           [-1.5105e+00, -1.5105e+00, -1.5102e+00,  ...,  2.1750e+00,
#             2.1651e+00,  2.1651e+00]],
#
#          [[-1.2990e+00, -1.3292e+00, -1.3409e+00,  ..., -2.2942e-01,
#            -2.4216e-01, -2.5325e-01],
#           [-1.2932e+00, -1.3268e+00, -1.3418e+00,  ..., -2.0963e-01,
#            -2.2615e-01, -2.5470e-01],
#           [-1.2252e+00, -1.2957e+00, -1.3478e+00,  ..., -2.4928e-01,
#            -2.6060e-01, -2.7068e-01],
#           ...,
#           [-1.0550e+00, -1.0538e+00, -1.0530e+00,  ...,  2.3355e+00,
#             2.3368e+00,  2.3457e+00],
#           [-1.0550e+00, -1.0550e+00, -1.0502e+00,  ...,  2.3522e+00,
#             2.3429e+00,  2.3437e+00],
#           [-1.0550e+00, -1.0550e+00, -1.0547e+00,  ...,  2.3706e+00,
#             2.3603e+00,  2.3603e+00]]],
#
#
#         [[[ 1.0073e-01,  1.1213e-02, -9.4580e-02,  ...,  6.9056e-01,
#             6.9056e-01,  6.9056e-01],
#           [ 5.3524e-03,  2.2045e-03,  5.8576e-02,  ...,  6.9056e-01,
#             6.9056e-01,  6.9056e-01],
#           [-2.1854e-02, -5.8668e-02, -1.5241e-01,  ...,  6.9010e-01,
#             6.8920e-01,  6.8584e-01],
#           ...,
#           [ 6.0695e-01,  3.7563e-01,  2.3760e-01,  ...,  2.5433e-01,
#             9.3656e-01,  9.7673e-01],
#           [ 8.0383e-01,  2.4343e-01,  4.6422e-01,  ...,  7.4825e-02,
#             1.0898e+00,  1.0610e+00],
#           [ 9.2613e-01,  9.6396e-02,  6.9662e-01,  ..., -8.6950e-02,
#             1.0503e+00,  1.1199e+00]],
#
#          [[ 2.2200e-01,  1.3537e-01,  3.2773e-02,  ...,  3.6393e-01,
#             3.6627e-01,  3.6627e-01],
#           [ 1.4353e-01,  1.3328e-01,  1.8640e-01,  ...,  3.6819e-01,
#             3.7900e-01,  3.7900e-01],
#           [ 1.0701e-01,  6.1860e-02, -4.6277e-02,  ...,  3.7225e-01,
#             3.7887e-01,  3.7543e-01],
#           ...,
#           [ 1.0177e+00,  7.7100e-01,  6.1836e-01,  ...,  6.3943e-01,
#             1.3678e+00,  1.4343e+00],
#           [ 1.2339e+00,  6.5685e-01,  8.7797e-01,  ...,  4.5358e-01,
#             1.5081e+00,  1.5017e+00],
#           [ 1.3843e+00,  5.3608e-01,  1.1489e+00,  ...,  2.8418e-01,
#             1.4576e+00,  1.5320e+00]],
#
#          [[ 6.1752e-01,  5.4759e-01,  4.7997e-01,  ...,  4.0789e-01,
#             4.0555e-01,  4.0555e-01],
#           [ 5.5245e-01,  5.6965e-01,  6.5499e-01,  ...,  4.0364e-01,
#             3.9288e-01,  3.9288e-01],
#           [ 5.5442e-01,  5.3924e-01,  4.6618e-01,  ...,  3.9868e-01,
#             3.9026e-01,  3.8683e-01],
#           ...,
#           [ 1.5379e+00,  1.2973e+00,  1.1502e+00,  ...,  1.1786e+00,
#             1.9151e+00,  2.0063e+00],
#           [ 1.7469e+00,  1.1745e+00,  1.3963e+00,  ...,  1.0024e+00,
#             2.0548e+00,  2.0744e+00],
#           [ 1.8967e+00,  1.0522e+00,  1.6618e+00,  ...,  8.3679e-01,
#             2.0045e+00,  2.1137e+00]]]])
# tensor([ 84,  14,  77, 141,  37, 176, 237,  36, 238,  71, 229,  69, 226,  88,
#         143,  29,  84,  14,  77, 141,  37, 176, 237,  36, 238,  71, 229,  69,
#         226,  88, 143,  29])

# %%
print(img.shape)
# Out:
# torch.Size([32, 3, 224, 224])

# %%
import os
tmp = os.listdir("/mnt/bn/data-tns-live-llm/leon/experiments/llm/face/second_stage_train_imgs_2m")
print(len(tmp))
# Out:
# 176415

# %%
import json
with open("/mnt/bn/data-tns-live-llm/leon/experiments/llm/face/processed_pair_face_2m.json", "r") as f:
    data = json.loads(f.read())

# %%
root = "/mnt/bn/data-tns-live-llm/leon/experiments/llm/face/second_stage_train_imgs_2m"
cnt = 0
for d in data:
    if os.path.exists(f'{root}/{d["room_id"]}/{d["object1"]}'):
        cnt += len(os.listdir(f'{root}/{d["room_id"]}/{d["object1"]}'))
    if os.path.exists(f'{root}/{d["room_id"]}/{d["object2"]}'):
        cnt += len(os.listdir(f'{root}/{d["room_id"]}/{d["object2"]}'))
print(cnt)
# Out:
# 3115411

# %%
import torch
model = torch.load("/mnt/bn/data-tns-live-llm/leon/experiments/llm/face/trained_model_2m/checkpoint_0000.pth.tar")
print(model.keys())
# Out:
# dict_keys(['epoch', 'arch', 'state_dict', 'optimizer'])

# %%
print(model["state_dict"].keys())

# %% [markdown]
# # 测试face.py

# %%
import sys
sys.path.append("/opt/tiger/SimCLR")
from data_aug.face import Face
from data_aug.contrastive_learning_dataset import ContrastiveLearningDataset

# %%
dataset = ContrastiveLearningDataset("/mnt/bn/data-tns-live-llm/leon/experiments/llm/face/cropped_second_stage_imgs_2million/")
train_dataset = dataset.get_dataset("moco", 2)

# %%
print(len(train_dataset))
# Out:
# 450324

# %%
tmp = train_dataset[0]

# %%
print(tmp[0][0].shape)
# Out:
# torch.Size([3, 224, 224])
